# %% [markdown]
# # How to calculate Zwicker loudness from .wav file (steady signal)

# %% [markdown]
# MoSQITo is a unified and modular development framework of key sound quality metrics favoring reproducible science and efficient shared scripting among engineers, teachers and researchers community.
#
# This tutorial explains how to calculate the acoustic loudness (Zwicker method) of a steady signal from a .wav file

# %%
# Add MoSQITo to the Python path
import sys
sys.path.append('..')

#local applications imports
from mosqito.Classes.Audio_signal import Audio_signal

# %% [markdown]
# The audio signal object to be analyzed is created according to the "Audio_signal" class which needs 3 parameters : the signal type, its path, its spectrum. Here we are using a .wav file as an entry so have to declare its path.
#
# For this tutorial, the test signal n°3 from ISO 532-1 annex B3 is used (1 kHz tone in free field with a level of 60 dB). According to the standard, for the calibration of the WAVE file, 0 dB (relative to full scale) shall correspond to a sound pressure level of 100 dB.

# %%
audio=Audio_signal('stationary','../mosqito/tests/data/ISO_532-1/Test signal 3 (1 kHz 60 dB).wav')

# %% [markdown]
# First the .wav file is loaded using the "load_wav" method, and then converted to third octave band spectrum using the "comp_third_oct" method. By default, the script calculate 28 third octave levels from 25 Hz to 12500 Hz in dB re. 2.10−5 Pa. The calib input argument is used to convert the .wav data to Pa.

# %%
audio.load_wav()
audio.comp_third_oct()

# %% [markdown]
# The signal amplitude can be plotted according to the frequency.

# %%
audio.plot_freq()

# %% [markdown]
# Then the "comp_loudness" method is called to calculate the loudness N in sones, the specific loudness N_specific in sones/Bark and the corresponding critical band rate scale bark_axis in Bark.

# %%
audio.comp_loudness()
# Out:
# Loudness: 4.052 sones

# %% [markdown]
# Finally, the loudness can be plotted according to the frequency and the Bark scale.

# %%
audio.plot_loudness()
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array
#   alpha: float or None
#   animated: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   contains: unknown
#   figure: `.Figure`
#   gid: str
#   in_layout: bool
#   label: str
#   label1: str
#   label2: str
#   pad: float
#   path_effects: `.AbstractPathEffect`
#   picker: None or bool or callable
#   rasterized: bool or None
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   transform: `.Transform`
#   url: str
#   visible: bool
#   zorder: float
